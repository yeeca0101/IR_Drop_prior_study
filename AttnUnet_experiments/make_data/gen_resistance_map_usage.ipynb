# %% [markdown]
# ### Only for BeGAN real-circuit-benchmarks-asap7
#     - Extract Resistance

# %%
from gen_resistance_map import process_all_sp_files_asap7_testcase,process_all_sp_files_train # testcase folder // train folder

# %%
root_dir = '/data/real-circuit-benchmarks/asap7/data'
output_dir = '/data/real-circuit-benchmarks/asap7/numpy_data'
# show_only를 True로 설정하면 시각화 결과를 저장하지 않고 화면에만 표시합니다.
process_all_sp_files_asap7_testcase(root_dir, output_dir, show_only=False)
# Out:
# Processing jpeg_reg_grid.sp.gz with available CSV files {'current_map': '/data/real-circuit-benchmarks/asap7/data/jpeg_current_map.csv.gz', 'voltage_map_irregular': '/data/real-circuit-benchmarks/asap7/data/jpeg_voltage_map_irregular.csv.gz', 'voltage_map_regular': '/data/real-circuit-benchmarks/asap7/data/jpeg_voltage_map_regular.csv.gz', 'irreg_grid': '/data/real-circuit-benchmarks/asap7/data/jpeg_irreg_grid.sp.gz', 'reg_grid': '/data/real-circuit-benchmarks/asap7/data/jpeg_reg_grid.sp.gz'}...
# Process completed. Results saved in /data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg
# ...

# %%
root_dir = '/data/BeGAN-circuit-benchmarks/asap7/data'
output_dir = '/data/BeGAN-circuit-benchmarks/asap7/numpy_data/BeGAN'

# show_only를 True로 설정하면 시각화 결과를 저장하지 않고 화면에만 표시합니다.
process_all_sp_files_train(root_dir, output_dir, show_only=False,
                     target_layers=['m2', 'm5', 'm6', 'm7', 'm8', 'm25', 'm56', 'm67', 'm78'])
# Out:
# Processing BeGAN_537_reg_grid.sp.gz with CSV files {'current_map': '/data/BeGAN-circuit-benchmarks/asap7/data/BeGAN_537_current_map.csv.gz'}...
# Process completed. Results saved in /data/BeGAN-circuit-benchmarks/asap7/numpy_data/BeGAN/layer_data
# Processing BeGAN_444_reg_grid.sp.gz with CSV files {'current_map': '/data/BeGAN-circuit-benchmarks/asap7/data/BeGAN_444_current_map.csv.gz'}...
# Process completed. Results saved in /data/BeGAN-circuit-benchmarks/asap7/numpy_data/BeGAN/layer_data
# Processing BeGAN_734_reg_grid.sp.gz with CSV files {'current_map': '/data/BeGAN-circuit-benchmarks/asap7/data/BeGAN_734_current_map.csv.gz'}...
# Process completed. Results saved in /data/BeGAN-circuit-benchmarks/asap7/numpy_data/BeGAN/layer_data
# Processing BeGAN_938_reg_grid.sp.gz with CSV files {'current_map': '/data/BeGAN-circuit-benchmarks/asap7/data/BeGAN_938_current_map.csv.gz'}...
# Process completed. Results saved in /data/BeGAN-circuit-benchmarks/asap7/numpy_data/BeGAN/layer_data
# ...

# %%
len([{'current': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/dynamic_node_current_map.npy', 'voltage': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/dynamic_node_voltage_map_regular.npy', 'resistances': {'m2': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m2_resistance_matrix.npy', 'm5': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m5_resistance_matrix.npy', 'm6': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m6_resistance_matrix.npy', 'm7': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m7_resistance_matrix.npy', 'm8': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m8_resistance_matrix.npy', 'm25': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m25_resistance_matrix.npy', 'm56': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m56_resistance_matrix.npy', 'm67': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m67_resistance_matrix.npy', 'm78': '/data/real-circuit-benchmarks/asap7/numpy_data/dynamic/layer_data/reg/m78_resistance_matrix.npy'}}, {'current': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/ibex_current_map.npy', 'voltage': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/ibex_voltage_map_regular.npy', 'resistances': {'m2': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m2_resistance_matrix.npy', 'm5': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m5_resistance_matrix.npy', 'm6': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m6_resistance_matrix.npy', 'm7': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m7_resistance_matrix.npy', 'm8': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m8_resistance_matrix.npy', 'm25': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m25_resistance_matrix.npy', 'm56': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m56_resistance_matrix.npy', 'm67': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m67_resistance_matrix.npy', 'm78': '/data/real-circuit-benchmarks/asap7/numpy_data/ibex/layer_data/reg/m78_resistance_matrix.npy'}}, {'current': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/aes_current_map.npy', 'voltage': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/aes_voltage_map_regular.npy', 'resistances': {'m2': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m2_resistance_matrix.npy', 'm5': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m5_resistance_matrix.npy', 'm6': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m6_resistance_matrix.npy', 'm7': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m7_resistance_matrix.npy', 'm8': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m8_resistance_matrix.npy', 'm25': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m25_resistance_matrix.npy', 'm56': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m56_resistance_matrix.npy', 'm67': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m67_resistance_matrix.npy', 'm78': '/data/real-circuit-benchmarks/asap7/numpy_data/aes/layer_data/reg/m78_resistance_matrix.npy'}}, {'current': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/jpeg_current_map.npy', 'voltage': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/jpeg_voltage_map_regular.npy', 'resistances': {'m2': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m2_resistance_matrix.npy', 'm5': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m5_resistance_matrix.npy', 'm6': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m6_resistance_matrix.npy', 'm7': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m7_resistance_matrix.npy', 'm8': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m8_resistance_matrix.npy', 'm25': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m25_resistance_matrix.npy', 'm56': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m56_resistance_matrix.npy', 'm67': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m67_resistance_matrix.npy', 'm78': '/data/real-circuit-benchmarks/asap7/numpy_data/jpeg/layer_data/reg/m78_resistance_matrix.npy'}}])
# Out:
# 4

# %%
from gen_resistance_map import ResistanceMapExtractor

# %%
ResistanceMapExtractor()
